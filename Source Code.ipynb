# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import nltk
from nltk.tokenize import word_tokenize
import syllables
import os
from tqdm import tqdm

# Download required NLTK resources (run this once)
nltk.download("punkt")

# Function to fetch the HTML content of a URL
def fetch_html_content(url):
    response = requests.get(url)
    if response.status_code == 200:
        return response.text
    else:
        print(f"Failed to fetch content from {url}")
        return None

# Function to extract article title and text from HTML
def extract_article_data(html_content):
    soup = BeautifulSoup(html_content, "html.parser")
    article_title_element = soup.find("title")  # Find the <title> tag for the article title
    article_text_elements = soup.find_all("p")  # Find all <p> tags for the article text

    article_title = article_title_element.text.strip() if article_title_element else ""
    article_text = "\n".join([element.text.strip() for element in article_text_elements]) if article_text_elements else ""
    
    return article_title, article_text


# Function to calculate sentimental analysis
def sentimental_analysis(text, positive_words, negative_words):
    tokens = word_tokenize(text.lower())
    positive_score = sum(1 for word in tokens if word in positive_words)
    negative_score = sum(1 for word in tokens if word in negative_words)
    if positive_score + negative_score == 0:
        polarity_score = 0
        subjectivity_score = 0
    else:
        polarity_score = (positive_score - negative_score) / (positive_score + negative_score)
        subjectivity_score = (positive_score + negative_score) / len(tokens)
    return positive_score, negative_score, polarity_score, subjectivity_score

def text_analysis(text, stop_words):
    words = word_tokenize(text)
    sentences = nltk.sent_tokenize(text)

    complex_words = [word for word in words if len(word) > 2 and word.isalpha()]

    if len(sentences) == 0:
        avg_sentence_length = 0
        percentage_complex_words = 0
    else:
        # Remove stop words from the words list
        words = [word for word in words if word.lower() not in stop_words]

        # Calculate average sentence length
        avg_sentence_length = len(words) / len(sentences)

        # Calculate percentage of complex words
        if len(words) == 0:
            percentage_complex_words = 0
        else:
            percentage_complex_words = len(complex_words) / len(words)

    fog_index = 0.4 * (avg_sentence_length + percentage_complex_words)

    if len(sentences) == 0:
        avg_words_per_sentence = 0
    else:
        avg_words_per_sentence = len(words) / len(sentences)

    word_count = len(words)

    if len(words) == 0:
        syllable_count_per_word = 0
    else:
        syllable_count_per_word = sum([syllables.estimate(word) for word in words]) / len(words)

    personal_pronouns = ["i", "we", "my", "ours", "us"]
    personal_pronouns_count = sum(1 for word in words if word.lower() in personal_pronouns)

    if len(words) == 0:
        avg_word_length = 0
    else:
        total_chars = sum(len(word) for word in words)
        avg_word_length = total_chars / len(words)

    return (
        avg_sentence_length,
        percentage_complex_words,
        fog_index,
        avg_words_per_sentence,
        len(complex_words),  # Use len(complex_words) directly here
        word_count,
        syllable_count_per_word,
        personal_pronouns_count,
        avg_word_length,
    )

# Read positive and negative words from text files
positive_words = set()
negative_words = set()

with open("/Users/vikranthreddimasu/Downloads/Assignment/positive-words.txt", "r", encoding="latin-1") as file:
    positive_words.update(file.read().splitlines())

with open("/Users/vikranthreddimasu/Downloads/Assignment/negative-words.txt", "r", encoding="latin-1") as file:
    negative_words.update(file.read().splitlines())

# Read stop words from the text files
stop_words = set()
stop_words_files = [
    "StopWords_Auditor.txt",
    "StopWords_Currencies.txt",
    "StopWords_DatesandNumbers.txt",
    "StopWords_Generic.txt",
    "StopWords_GenericLong.txt",
    "StopWords_Geographic.txt",
    "StopWords_Names.txt",
]

for stop_words_file in stop_words_files:
    with open(f"/Users/vikranthreddimasu/Downloads/Assignment/{stop_words_file}", "r", encoding="latin-1") as file:
        stop_words.update(file.read().splitlines())

# Read the URLs from the input Excel file
input_file_path = "/Users/vikranthreddimasu/Downloads/Assignment/input.xlsx"
df_urls = pd.read_excel(input_file_path)

# Create a new DataFrame to store the results
results_df = pd.DataFrame(columns=[
    "URL_ID", "URL", "Article Title", "Article Text", "Positive Score", "Negative Score",
    "Polarity Score", "Subjectivity Score", "Avg Sentence Length", "Percentage of Complex Words",
    "Fog Index", "Avg Words per Sentence", "Complex Word Count", "Word Count", "Syllable per Word",
    "Personal Pronouns", "Avg Word Length",
])

for index, row in tqdm(df_urls.iterrows(), total=df_urls.shape[0], desc="Processing URLs"):
    url = row["URL"]
    try:
        html_content = fetch_html_content(url)
        if html_content:
            article_title, article_text = extract_article_data(html_content)

            # Save the extracted article text to a text file
            file_name = f"{row['URL_ID']}.txt"
            file_path = os.path.join("/Users/vikranthreddimasu/Downloads/Assignment/ExtractedArticles", file_name)

            with open(file_path, "w", encoding="utf-8") as text_file:
                text_file.write(article_text)

            # Sentimental analysis
            positive_score, negative_score, polarity_score, subjectivity_score = sentimental_analysis(
                article_text, positive_words, negative_words
            )

            # Text analysis
            text_analysis_results = text_analysis(article_text, stop_words)

            results_df = results_df.append(
                {
                    "URL_ID": row["URL_ID"], "URL": url, "Article Title": article_title,
                    "Article Text": article_text, "Positive Score": positive_score,
                    "Negative Score": negative_score, "Polarity Score": polarity_score,
                    "Subjectivity Score": subjectivity_score, "Avg Sentence Length": text_analysis_results[0],
                    "Percentage of Complex Words": text_analysis_results[1], "Fog Index": text_analysis_results[2],
                    "Avg Words per Sentence": text_analysis_results[3], "Complex Word Count": text_analysis_results[4],
                    "Word Count": text_analysis_results[5], "Syllable per Word": text_analysis_results[6],
                    "Personal Pronouns": text_analysis_results[7], "Avg Word Length": text_analysis_results[8],
                },
                ignore_index=True,
            )
    except Exception as e:
        print(f"An error occurred for URL: {url}")
        print(f"Error: {str(e)}")

# Save the results DataFrame to an Excel file
output_file_path = "/Users/vikranthreddimasu/Downloads/Assignment/output_results.xlsx"
results_df.to_excel(output_file_path, index=False)

print("Data extraction and analysis completed. Results saved to:", output_file_path)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/vikranthreddimasu/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Processing URLs:   0%|                                  | 0/114 [00:00<?, ?it/s]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:   1%|▏                         | 1/114 [00:01<03:43,  1.98s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:   2%|▍                         | 2/114 [00:05<04:52,  2.61s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:   3%|▋                         | 3/114 [00:07<04:57,  2.68s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:   4%|▉                         | 4/114 [00:10<04:38,  2.53s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:   4%|█▏                        | 5/114 [00:12<04:35,  2.53s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:   5%|█▎                        | 6/114 [00:15<04:34,  2.54s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:   7%|█▊                        | 8/114 [00:19<04:03,  2.30s/it]
# Failed to fetch content from https://insights.blackcoffer.com/how-neural-networks-can-be-applied-in-various-areas-in-the-future/
# /var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:   8%|██                        | 9/114 [00:21<03:55,  2.24s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:   9%|██▏                      | 10/114 [00:24<04:02,  2.33s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  10%|██▍                      | 11/114 [00:26<04:02,  2.36s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  11%|██▋                      | 12/114 [00:28<04:01,  2.37s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  11%|██▊                      | 13/114 [00:31<04:06,  2.44s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  12%|███                      | 14/114 [00:33<04:04,  2.45s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  13%|███▎                     | 15/114 [00:36<04:11,  2.54s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  14%|███▌                     | 16/114 [00:38<03:57,  2.42s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  15%|███▋                     | 17/114 [00:41<03:54,  2.42s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  16%|███▉                     | 18/114 [00:43<03:51,  2.42s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  17%|████▏                    | 19/114 [00:45<03:44,  2.37s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  18%|████▌                    | 21/114 [00:50<03:34,  2.30s/it]
# Failed to fetch content from https://insights.blackcoffer.com/covid-19-environmental-impact-for-the-future/
# /var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  19%|████▊                    | 22/114 [00:52<03:41,  2.41s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  20%|█████                    | 23/114 [00:55<03:31,  2.33s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  21%|█████▎                   | 24/114 [00:57<03:42,  2.47s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  22%|█████▍                   | 25/114 [00:59<03:27,  2.33s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  23%|█████▋                   | 26/114 [01:02<03:20,  2.28s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  24%|█████▉                   | 27/114 [01:04<03:22,  2.33s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  25%|██████▏                  | 28/114 [01:06<03:16,  2.28s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  25%|██████▎                  | 29/114 [01:08<03:08,  2.22s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  26%|██████▌                  | 30/114 [01:10<03:06,  2.22s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  27%|██████▊                  | 31/114 [01:13<03:10,  2.29s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  28%|███████                  | 32/114 [01:16<03:34,  2.62s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  29%|███████▏                 | 33/114 [01:19<03:27,  2.57s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  30%|███████▍                 | 34/114 [01:21<03:14,  2.43s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  31%|███████▋                 | 35/114 [01:23<03:06,  2.36s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  32%|███████▉                 | 36/114 [01:25<03:00,  2.31s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  32%|████████                 | 37/114 [01:28<03:03,  2.38s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  33%|████████▎                | 38/114 [01:30<03:06,  2.46s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  34%|████████▌                | 39/114 [01:33<03:04,  2.46s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  35%|████████▊                | 40/114 [01:36<03:11,  2.58s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  36%|████████▉                | 41/114 [01:38<03:04,  2.53s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  37%|█████████▏               | 42/114 [01:41<02:59,  2.49s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  38%|█████████▍               | 43/114 [01:43<02:48,  2.38s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  39%|█████████▋               | 44/114 [01:45<02:40,  2.30s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  39%|█████████▊               | 45/114 [01:47<02:43,  2.37s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  40%|██████████               | 46/114 [01:50<02:41,  2.38s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  41%|██████████▎              | 47/114 [01:54<03:08,  2.82s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  42%|██████████▌              | 48/114 [02:25<12:28, 11.34s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  43%|██████████▋              | 49/114 [02:27<09:18,  8.59s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  44%|██████████▉              | 50/114 [02:29<07:11,  6.74s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  45%|███████████▏             | 51/114 [02:32<05:46,  5.49s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  46%|███████████▍             | 52/114 [02:34<04:42,  4.56s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  46%|███████████▌             | 53/114 [02:37<04:00,  3.94s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  47%|███████████▊             | 54/114 [02:39<03:27,  3.46s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  48%|████████████             | 55/114 [02:42<03:06,  3.17s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  49%|████████████▎            | 56/114 [02:45<02:58,  3.08s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  50%|████████████▌            | 57/114 [02:47<02:50,  2.99s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  51%|████████████▋            | 58/114 [02:50<02:47,  2.98s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  52%|████████████▉            | 59/114 [02:52<02:29,  2.72s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  53%|█████████████▏           | 60/114 [02:55<02:26,  2.71s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  54%|█████████████▍           | 61/114 [02:57<02:16,  2.58s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  54%|█████████████▌           | 62/114 [03:00<02:07,  2.45s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  55%|█████████████▊           | 63/114 [03:02<02:03,  2.43s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  56%|██████████████           | 64/114 [03:05<02:09,  2.58s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  57%|██████████████▎          | 65/114 [03:07<02:04,  2.53s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  58%|██████████████▍          | 66/114 [03:09<01:55,  2.40s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  59%|██████████████▋          | 67/114 [03:11<01:46,  2.27s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  60%|██████████████▉          | 68/114 [03:13<01:41,  2.20s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  61%|███████████████▏         | 69/114 [03:15<01:37,  2.17s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  61%|███████████████▎         | 70/114 [03:18<01:39,  2.27s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  62%|███████████████▌         | 71/114 [03:21<01:44,  2.43s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  63%|███████████████▊         | 72/114 [03:23<01:41,  2.43s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  64%|████████████████         | 73/114 [03:26<01:39,  2.43s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  65%|████████████████▏        | 74/114 [03:28<01:34,  2.35s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  66%|████████████████▍        | 75/114 [03:30<01:34,  2.42s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  67%|████████████████▋        | 76/114 [03:33<01:31,  2.40s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  68%|████████████████▉        | 77/114 [03:35<01:30,  2.44s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  68%|█████████████████        | 78/114 [03:38<01:30,  2.50s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  69%|█████████████████▎       | 79/114 [03:40<01:28,  2.53s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  70%|█████████████████▌       | 80/114 [03:43<01:22,  2.42s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  71%|█████████████████▊       | 81/114 [03:45<01:22,  2.49s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  72%|█████████████████▉       | 82/114 [03:48<01:17,  2.42s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  73%|██████████████████▏      | 83/114 [03:50<01:13,  2.38s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  74%|██████████████████▍      | 84/114 [03:52<01:12,  2.41s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  75%|██████████████████▋      | 85/114 [03:55<01:08,  2.38s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  75%|██████████████████▊      | 86/114 [03:57<01:09,  2.50s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  76%|███████████████████      | 87/114 [04:00<01:07,  2.48s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  77%|███████████████████▎     | 88/114 [04:02<01:04,  2.47s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  78%|███████████████████▌     | 89/114 [04:05<01:03,  2.55s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  79%|███████████████████▋     | 90/114 [04:07<00:58,  2.44s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  80%|███████████████████▉     | 91/114 [04:10<00:58,  2.54s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  81%|████████████████████▏    | 92/114 [04:12<00:53,  2.42s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  82%|████████████████████▍    | 93/114 [04:14<00:49,  2.34s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  82%|████████████████████▌    | 94/114 [04:17<00:50,  2.53s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  83%|████████████████████▊    | 95/114 [04:20<00:47,  2.51s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  84%|█████████████████████    | 96/114 [04:22<00:44,  2.49s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  85%|█████████████████████▎   | 97/114 [04:24<00:40,  2.38s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  86%|█████████████████████▍   | 98/114 [04:26<00:37,  2.31s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  87%|█████████████████████▋   | 99/114 [04:28<00:33,  2.21s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  88%|█████████████████████   | 100/114 [04:31<00:30,  2.19s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  89%|█████████████████████▎  | 101/114 [04:33<00:28,  2.21s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  89%|█████████████████████▍  | 102/114 [04:35<00:26,  2.22s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  90%|█████████████████████▋  | 103/114 [04:37<00:24,  2.20s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  91%|█████████████████████▉  | 104/114 [04:39<00:21,  2.19s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  92%|██████████████████████  | 105/114 [04:42<00:20,  2.25s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  93%|██████████████████████▎ | 106/114 [04:44<00:18,  2.28s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  95%|██████████████████████▋ | 108/114 [04:49<00:13,  2.23s/it]
# Failed to fetch content from https://insights.blackcoffer.com/ensuring-growth-through-insurance-technology/
# /var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  96%|██████████████████████▉ | 109/114 [04:51<00:11,  2.21s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  96%|███████████████████████▏| 110/114 [04:53<00:08,  2.21s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  97%|███████████████████████▎| 111/114 [04:55<00:06,  2.28s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  98%|███████████████████████▌| 112/114 [04:58<00:04,  2.25s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs:  99%|███████████████████████▊| 113/114 [05:00<00:02,  2.19s/it]/var/folders/cz/67qdp5mj02v65zzkh907n_v80000gn/T/ipykernel_5672/3797494825.py:164: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(
# Processing URLs: 100%|████████████████████████| 114/114 [05:02<00:00,  2.65s/it]
# Data extraction and analysis completed. Results saved to: /Users/vikranthreddimasu/Downloads/Assignment/output_results.xlsx
